# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import numpy as np
from collections import Counter

# %%
with open(os.path.join('..', 'data', 'train.csv'), 'rb') as csvfile:
    training_data = np.loadtxt(csvfile, delimiter=',')

# %%
# Shows the images of character at particular index of data
def show_char(data, index):
    plt.imshow(data[index, 9:439].reshape([33,13]), cmap='Greys_r')
    
# Shows the images of char from data, up to number of images shown
def show_chars_like(data, char, number, book=-1):
    if book == -1:
        selected_data = random.permutation([x for x in data if x[1] == char])
    else:
        selected_data = random.permutation([x for x in data if x[1] == char and x[2] == book])
        
    entries = min(number, selected_data.shape[0])
    print(entries)
    for i in range(entries):
        show_char(selected_data, i)
        plt.show()

# %%
# Number of samples from each book
Counter(training_data[:, 2])
# Out:
# Counter({0.0: 8332, 1.0: 5965, 2.0: 14648, 3.0: 4408, 4.0: 10608, 5.0: 6321})

# %%
# Highly common characters
[{a:b} for a,b in Counter(training_data[:, 1]).items() if b>1000]
# Out:
# [{64.0: 5215},
#  {66.0: 2804},
#  {67.0: 1174},
#  {68.0: 4257},
#  {71.0: 1104},
#  {72.0: 5466},
#  {74.0: 2922},
#  {75.0: 1587},
#  {76.0: 3577},
#  {77.0: 3928},
#  {78.0: 1054},
#  {80.0: 1553},
#  {82.0: 3251},
#  {83.0: 2554},
#  {86.0: 1013},
#  {97.0: 1244}]

# %%
show_chars_like(training_data, 64, 50, book=0)
# Out:
# 50

# %%
show_chars_like(training_data, 64, 5, book=1)
# Out:
# 5

# %%
show_chars_like(training_data, 64, 5, book=2)
# Out:
# 5

# %%
show_chars_like(training_data, 64, 5, book=3)
# Out:
# 5

# %%
show_chars_like(training_data, 64, 5, book=4)
# Out:
# 5

# %%
show_chars_like(training_data, 64, 10, book=5)
# Out:
# 10

# %%
with open(os.path.join('..', 'kerasCNN_Preprocessed_No_Book_5_5_noheader.csv'), 'rb') as csvfile:
    predicted_data = np.loadtxt(csvfile, delimiter=',')
with open(os.path.join('..', 'data', 'test.csv'), 'rb') as csvfile:
    test_data = np.loadtxt(csvfile, delimiter=',')

# %%
full_predict_data = np.hstack((predicted_data, test_data[:,9:439]))

# %%
from collections import Counter

# %%
Counter(full_predict_data[:,1])
# Out:
# Counter({5.0: 185,
#          6.0: 41,
#          7.0: 112,
#          8.0: 1,
#          19.0: 21,
#          22.0: 7,
#          24.0: 6,
#          25.0: 15,
#          26.0: 12,
#          30.0: 3,
#          31.0: 1,
#          32.0: 3,
#          33.0: 5,
#          34.0: 8,
#          36.0: 3,
#          38.0: 5,
#          39.0: 3,
#          40.0: 6,
#          42.0: 9,
#          45.0: 1,
#          52.0: 10,
#          54.0: 12,
#          55.0: 1,
#          57.0: 20,
#          58.0: 1,
#          59.0: 21,
#          62.0: 2,
#          64.0: 980,
#          65.0: 56,
#          66.0: 421,
#          67.0: 300,
#          68.0: 858,
#          69.0: 37,
#          70.0: 71,
#          71.0: 117,
#          72.0: 905,
#          73.0: 2,
#          74.0: 484,
#          75.0: 237,
#          76.0: 597,
#          77.0: 689,
#          78.0: 186,
#          79.0: 174,
#          80.0: 348,
#          81.0: 174,
#          82.0: 477,
#          83.0: 471,
# ...

# %%
temp = np.array([x for x in full_predict_data if x[1] == 93])
for img in temp[-100:]:
    plt.imshow(img[2:].reshape([33,13]), cmap='gray')
    plt.show()

# %%
temp = np.array([x for x in full_predict_data if x[1] == 64])
fig = plt.figure()
for i, img in enumerate(temp[-100:]):
    fig.add_subplot(10, 10, i+1)
    plot = plt.imshow(255 - img[2:].reshape([33,13]), cmap='gray')
    plt.axis('off')
    fig.savefig('img.png')
#     plt.imsave('img' + str(i) + '.png', 255 - img[2:].reshape([33,13]), cmap='gray')

# %%
# Out:
# '/Users/Shian/Programs/Python/Statistical-Machine-Learning-Project/Notebooks'
